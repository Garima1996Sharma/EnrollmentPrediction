# %% [markdown]
# # Lab2
# - ##### Name: Garima Sharma
# - ##### Student ID: 300343374

# %% [markdown]
# ## 1.1 Load the python library
# All the used libraries are mentioned below:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mp
import seaborn as sb

# %% [markdown]
# ## 1.2 Read the cleaned data

# %%
def load_course_data(filename):
    return pd.read_csv(filename)

# data is loaded here.
df = load_course_data("course_data_cleaned.csv")
df

# drop column unnamed
df.drop('Unnamed: 0', inplace=True, axis =1)
df
print("\n")

# checking for null rows/columns
print(df.isna().sum())

# dropping rows where any data are missing:
df.dropna(axis = 0, how = 'any', inplace = True)

print("\n")
print(df.head())

print("\n")
# provide the summary of the data types
df.info()
print("\n")

# reseting the index
df.reset_index(inplace=True, drop=True)
df
# Out:
# course_category     0
# avg_rating          3
# number_ratings      3
# enrollment          5
# last_updated        0
# lectures            4
# duration           16
# price2              0
# discount            0
# inst_rating         3
# inst_review         3
# inst_student        0
# inst_course         0
# dtype: int64
#
#
#         course_category  avg_rating  number_ratings  enrollment  last_updated  \
# 0                design         4.2          6340.0     54930.0         20.67
# 1  business_&_education         4.6          9281.0     48338.0         18.25
# 2           development         4.6          6833.0     21218.0         20.83
# 3           development         4.6         72122.0    717921.0         20.33
# 4  business_&_education         4.5          2826.0     14269.0         20.83
#
#    lectures  duration  price2  discount  inst_rating  inst_review  \
# 0     162.0     19.38   23.99      90.0          4.2      13453.0
# ...

# %% [markdown]
# ## 1.3 Exploratory Data Analysis
# ### 1.3.1 Display the statistics summary of the dataset

# %%
df.describe()
# Out:
#         avg_rating  number_ratings    enrollment  last_updated     lectures  \
# count  1936.000000     1936.000000  1.936000e+03   1936.000000  1936.000000
# mean      4.408368     4732.513946  2.555030e+04     19.853920   106.383264
# std       0.270557    14402.094582  6.148837e+04      1.334817   100.389164
# min       2.100000       17.000000  3.600000e+01     11.670000     5.000000
# 25%       4.300000      600.750000  3.706750e+03     19.420000    45.000000
# 50%       4.500000     1415.000000  9.288500e+03     20.420000    74.500000
# 75%       4.600000     3507.250000  2.139450e+04     20.750000   126.000000
# max       4.900000   321904.000000  1.112443e+06     20.830000   699.000000
#
#           duration       price2     discount  inst_rating    inst_review  \
# count  1936.000000  1936.000000  1936.000000  1936.000000    1936.000000
# mean     11.934706    23.515310    78.602273     4.413688   49452.677686
# ...

# %%
# providing the percentile values for 0.01, 0.25, 0.5, 0.75, 0.99

df1 = df.quantile([0.01,0.25,0.5,0.75,0.99])
df1
# Out:
#       avg_rating  number_ratings  enrollment  last_updated  lectures  \
# 0.01         3.4           70.00      342.20        14.948     11.00
# 0.25         4.3          600.75     3706.75        19.420     45.00
# 0.50         4.5         1415.00     9288.50        20.420     74.50
# 0.75         4.6         3507.25    21394.50        20.750    126.00
# 0.99         4.8        53808.15   308696.65        20.830    520.85
#
#       duration  price2  discount  inst_rating  inst_review  inst_student  \
# 0.01    1.2570   16.99      32.0          3.6       142.35         710.5
# 0.25    4.4200   16.99      74.0          4.3      2575.25       15995.0
# 0.50    7.8700   19.99      86.0          4.5     11423.00       63370.0
# 0.75   14.2550   21.99      89.0          4.6     45136.00      243668.0
# 0.99   64.8675  149.99      92.0          4.7    509993.00     1979353.0
#
#       inst_course
# 0.01          1.0
# 0.25          5.0
# 0.50         12.0
# 0.75         23.0
# ...

# %%
# display the maximum and minimum values

print(df.max())
print("\n")
print(df.min())
# Out:
# course_category    it_software
# avg_rating                 4.9
# number_ratings        321904.0
# enrollment           1112443.0
# last_updated             20.83
# lectures                 699.0
# duration                 164.0
# price2                  199.99
# discount                  92.0
# inst_rating                4.8
# inst_review           652986.0
# inst_student         2168985.0
# inst_course             1420.0
# dtype: object
#
#
# course_category    business_&_education
# avg_rating                          2.1
# number_ratings                     17.0
# enrollment                         36.0
# last_updated                      11.67
# lectures                            5.0
# duration                            1.0
# price2                            16.99
# discount                           30.0
# inst_rating                         2.6
# inst_review                        31.0
# inst_student                       55.0
# inst_course                         1.0
# ...

# %% [markdown]
# ### 1.3.2 Display the course(s) that has highest enrollment
#
# From the results mentioned below, we can see that course_categroy "design" has the maximum enrollment(1112443.3).

# %%
print(df.groupby('course_category').enrollment.agg(['max']))
# Out:
#                             max
# course_category
# business_&_education   548491.0
# design                 471435.0
# development           1112443.0
# hobby                  277769.0
# it_software            570234.0

# %% [markdown]
# ### 1.3.3 Display the course(s) that has lowest enrollment
#
# From the results mentioned below, we can see that course_categroy "business_&_education" has the minimum enrollment(36.0).

# %%
print(df.groupby('course_category').enrollment.agg(['min']))
# Out:
#                         min
# course_category
# business_&_education   36.0
# design                162.0
# development           258.0
# hobby                 254.0
# it_software           136.0

# %% [markdown]
# ### 1.3.4 Display the courses that has enrollment higher than its 99% percentile.
#
# From the results mentioned below, we can see that course_categroy "business_&_education, development, design and IT Software" has enrollment higher than its 99% percentile, which is 308696.65 in our case.

# %%
# find out the indexes of the data with enrollment>308696.65
df.enrollment > 308696.65
# to find the index
ind = df.loc[df.enrollment > 308696.65].index
print(ind)

# display the data
enroll = df.iloc[ind]
enroll[['course_category','enrollment']]
# Out:
# Int64Index([   3,  146,  170,  233,  332,  449,  510,  708,  758,  795,  804,
#              871,  978, 1006, 1195, 1238, 1334, 1349, 1519, 1810],
#            dtype='int64')
#            course_category  enrollment
# 3              development    717921.0
# 146                 design    406060.0
# 170            development    698344.0
# 233                 design    471435.0
# 332   business_&_education    378952.0
# 449            development    483700.0
# 510            development    352300.0
# 708            development    426876.0
# 758            development   1112443.0
# 795            development    507548.0
# 804            development    392197.0
# 871   business_&_education    548491.0
# 978            development    322013.0
# 1006           development    309943.0
# 1195           development    329517.0
# 1238           development    601069.0
# 1334  business_&_education    500447.0
# 1349           development    317793.0
# 1519           it_software    570234.0
# ...

# %% [markdown]
# ### 1.3.5 Display the courses that has average ratings higher than its 99% percentile.
#
# From the results mentioned below, we can see that course_categroy "development, design and hobby" has average rating higher than its 99% percentile, which is 4.8 in our case.

# %%
# find out the indexes of the data with average rating > 4.8
df.avg_rating > 4.8
# to find the index
ind1 = df.loc[df.avg_rating>4.8].index
print(ind1)

# display the data
above_avg = df.iloc[ind1]
above_avg[['course_category','avg_rating']]
# Out:
# Int64Index([89, 269, 426, 559, 1116, 1357, 1687, 1703], dtype='int64')
#      course_category  avg_rating
# 89       development         4.9
# 269      development         4.9
# 426            hobby         4.9
# 559           design         4.9
# 1116     development         4.9
# 1357           hobby         4.9
# 1687     development         4.9
# 1703          design         4.9

# %% [markdown]
# ### 1.3.6 Display the courses that has average ratings lower than its 1% percentile.
#
# From the results mentioned below, we can see that course_categroy "development, business_&_education and IT Software" has average rating lower than its 1% percentile, which is 3.4 in our case.

# %%
# find out the indexes of the data with average rating < 3.4
df.avg_rating<3.4
# to find the index
ind2 = df.loc[df.avg_rating<3.4].index
print(ind2)

# display the data
average = df.iloc[ind2]
average[['course_category','avg_rating']]
# Out:
# Int64Index([   5,  252,  283,  441,  817,  925, 1009, 1085, 1325, 1346, 1463,
#             1525, 1637, 1751, 1873, 1876],
#            dtype='int64')
#            course_category  avg_rating
# 5     business_&_education         3.3
# 252            it_software         3.3
# 283            it_software         2.1
# 441   business_&_education         3.0
# 817            it_software         2.5
# 925            it_software         2.6
# 1009           it_software         3.3
# 1085           it_software         3.3
# 1325           development         3.0
# 1346  business_&_education         3.2
# 1463           it_software         2.9
# 1525  business_&_education         2.7
# 1637           it_software         3.3
# 1751           it_software         3.0
# 1873           it_software         3.1
# 1876           it_software         3.3

# %% [markdown]
# ## 1.4 Display the Correlation

# %%
# calculates the correlation
df.corr()
# Out:
#                 avg_rating  number_ratings  enrollment  last_updated  \
# avg_rating        1.000000        0.149569    0.154722      0.020414
# number_ratings    0.149569        1.000000    0.904866      0.040440
# enrollment        0.154722        0.904866    1.000000      0.037941
# last_updated      0.020414        0.040440    0.037941      1.000000
# lectures          0.016656        0.091367    0.067693      0.109577
# duration         -0.026187        0.080847    0.063501      0.113117
# price2           -0.057624       -0.015911   -0.015354     -0.023893
# discount         -0.006088        0.018194    0.020906      0.063268
# inst_rating       0.795885        0.156784    0.153548      0.047038
# inst_review       0.182072        0.408287    0.428330      0.051358
# inst_student      0.133942        0.345647    0.442797      0.029147
# inst_course      -0.113843       -0.009122    0.006554     -0.052681
#
# ...

# %%
# absolute value of the correlation 
absolute_Corr = df.corr().abs()
# sorted value
absolute_Corr["enrollment"].sort_values(ascending=False)
# Out:
# enrollment        1.000000
# number_ratings    0.904866
# inst_student      0.442797
# inst_review       0.428330
# avg_rating        0.154722
# inst_rating       0.153548
# lectures          0.067693
# duration          0.063501
# last_updated      0.037941
# discount          0.020906
# price2            0.015354
# inst_course       0.006554
# Name: enrollment, dtype: float64

# %% [markdown]
# From the results mentioned above, we can see that number of ratings has high positive correlation with the enrollment. In addition to this, inst_student and inst_review also has moderate positive correlation with enrollment. Moreover, avg_rating and inst_rating has positive correlation which is not that strong.

# %% [markdown]
# ## 1.5 Univariate Analysis

# %%
# distribution and histogram plot of the enrollment
from scipy.stats import norm
sb.distplot(df.enrollment, fit=norm)
#sb.displot(df['enrollment'], color='g', bins=30)
# Out:
# C:\Users\sharm\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='enrollment', ylabel='Density'>

# %%
ind = df.loc[df.enrollment>= 50000].index

#drop the values
df.drop(ind, inplace=True)
sb.distplot(df.enrollment, fit=norm)
#sb.displot(df['enrollment'], color='g', bins=30)
# Out:
# C:\Users\sharm\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='enrollment', ylabel='Density'>

# %% [markdown]
# We can see that the enrollment distribution (after we removed some outliers)still has a longer tail on the right but is better than the previous one.

# %%
# reseting the index
df.reset_index(inplace=True, drop=True)
df
# Out:
#            course_category  avg_rating  number_ratings  enrollment  \
# 0     business_&_education         4.6          9281.0     48338.0
# 1              development         4.6          6833.0     21218.0
# 2     business_&_education         4.5          2826.0     14269.0
# 3     business_&_education         3.3           320.0      2088.0
# 4     business_&_education         4.4           991.0      3563.0
# ...                    ...         ...             ...         ...
# 1716           it_software         4.4           345.0      6212.0
# 1717  business_&_education         3.8           693.0      3254.0
# 1718  business_&_education         4.2          3459.0     13987.0
# 1719           it_software         4.5          4546.0     15793.0
# 1720  business_&_education         3.7           389.0      3161.0
#
#       last_updated  lectures  duration  price2  discount  inst_rating  \
# 0            18.25      37.0      3.90   16.99      56.0          4.5
# ...

# %%
# fitting plot for number of ratings
sb.distplot(df.number_ratings , fit=norm)
#sb.displot(df['number_ratings'], color='g', bins=30)
# Out:
# C:\Users\sharm\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='number_ratings', ylabel='Density'>

# %%
# dropping values for number of ratings
ind1 = df.loc[df.number_ratings>= 10000].index
ind1

#drop them
df.drop(ind1, inplace=True)
sb.distplot(df.number_ratings , fit=norm)
# Out:
# C:\Users\sharm\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='number_ratings', ylabel='Density'>

# %% [markdown]
# The number of ratings distribution does not follow normal distribution with as it still skewed to the right. Most of the ratings lie between 0 to 1300.

# %%
# reseting the index
df.reset_index(inplace=True, drop=True)
df
df.describe()
# Out:
#         avg_rating  number_ratings    enrollment  last_updated     lectures  \
# count  1707.000000     1707.000000   1707.000000   1707.000000  1707.000000
# mean      4.391740     1860.400703  10994.944933     19.841728   104.442296
# std       0.279584     1866.644507  10285.089403      1.342794    97.096021
# min       2.100000       17.000000     36.000000     11.670000     5.000000
# 25%       4.300000      540.000000   3280.000000     19.420000    44.000000
# 50%       4.400000     1165.000000   7300.000000     20.420000    74.000000
# 75%       4.600000     2587.500000  15840.500000     20.750000   125.000000
# max       4.900000     9963.000000  49052.000000     20.830000   699.000000
#
#           duration       price2     discount  inst_rating    inst_review  \
# count  1707.000000  1707.000000  1707.000000  1707.000000    1707.000000
# mean     11.728793    23.591054    78.400117     4.400059   35793.032806
# ...

# %%
# fitting plot for inst_reviews
sb.distplot(df.inst_review, fit=norm)
#sb.displot(df['inst_review'], color='g', bins=30)
# Out:
# C:\Users\sharm\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='inst_review', ylabel='Density'>

# %%
ind3 = df.loc[df.inst_review> 110000].index
print(ind3)

#drop them
df.drop(ind3, inplace=True)
sb.distplot(df.inst_review, fit=norm)
# reseting the index
df.reset_index(inplace=True, drop=True)
# Out:
# Int64Index([   0,    6,   26,   63,   86,   96,  104,  134,  137,  139,
#             ...
#             1610, 1613, 1621, 1622, 1629, 1659, 1666, 1668, 1683, 1692],
#            dtype='int64', length=144)
# C:\Users\sharm\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# The inst_review distribution does not follow normal distribution with as it still skewed to the right. It is not a good choice to consider it a feature.

# %%
# fitting the plot for inst_student
sb.distplot(df.inst_student, fit=norm)

#sb.displot(df['inst_student'], color='g', bins=30)
# Out:
# C:\Users\sharm\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='inst_student', ylabel='Density'>

# %%
ind3 = df.loc[df.inst_student > 450000].index
print(ind3)

# #drop them
df.drop(ind3, inplace=True)
sb.distplot(df.inst_student, fit=norm)
# reseting the index
df.reset_index(inplace=True, drop=True)
# Out:
# Int64Index([   4,   35,   37,   41,   43,  122,  161,  185,  221,  235,  334,
#              339,  348,  349,  374,  412,  423,  425,  463,  543,  552,  596,
#              618,  622,  653,  679,  696,  710,  727,  877,  887,  894,  902,
#              912,  958, 1001, 1010, 1128, 1236, 1250, 1295, 1337, 1349, 1355,
#             1384, 1386, 1400, 1408, 1428, 1439, 1456, 1476, 1521],
#            dtype='int64')
# C:\Users\sharm\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# The inst_student distribution does not follow normal distribution as it still skewed to the right but still we can consider it.

# %%
#fitting plot for average rating
sb.distplot(df.avg_rating, fit=norm)
#sb.displot(df['avg_rating'], color='g', bins=30)
# Out:
# C:\Users\sharm\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='avg_rating', ylabel='Density'>

# %%
ind3 = df.loc[df.avg_rating < 3.8].index
print(ind3)

# #drop them
df.drop(ind3, inplace=True)
sb.distplot(df.avg_rating, fit=norm)
# reseting the index
df.reset_index(inplace=True, drop=True)
# Out:
# Int64Index([   2,   32,   44,   48,   82,  156,  184,  193,  197,  217,  218,
#              316,  339,  361,  362,  399,  438,  469,  525,  571,  577,  635,
#              637,  669,  723,  787,  843,  851, 1006, 1033, 1050, 1088, 1144,
#             1168, 1175, 1179, 1193, 1197, 1211, 1220, 1259, 1274, 1275, 1281,
#             1319, 1324, 1367, 1368, 1371, 1411, 1445, 1461, 1464, 1491, 1509],
#            dtype='int64')
# C:\Users\sharm\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# The average rating distribution somehow follow some normal distribution.

# %% [markdown]
# ## 1.6 Multi/Bivarite Analysis

# %%
# relationship between enrollment and number_rating
mp.scatter(df.number_ratings, df.enrollment, color="orange")
mp.title("Enrollment vs number_rating of courses")
mp.xlabel("Number_rating")
mp.ylabel("Enrollment")
# Out:
# Text(0, 0.5, 'Enrollment')

# %% [markdown]
# We can see that as the number of ratings increases, enrollment in courses also increasing. There are more enrollments when ratings lie between 0 to 4000 approximately.

# %%
# relationship between enrollment and reviews
mp.scatter(df.inst_review, df.enrollment, color="orange")
mp.title("Enrollment vs review of courses")
mp.xlabel("Inst_reviewing")
mp.ylabel("Enrollment")
# Out:
# Text(0, 0.5, 'Enrollment')

# %% [markdown]
# We can see that more enrollments when there are approximately reviews from 0 to 25000. After that, reviews are steady.

# %%
# relationship between enrollment and average_rating
mp.scatter(df.avg_rating, df.enrollment, color="orange");
mp.title("Enrollment vs average rating of courses", color="red");
mp.xlabel("Avg_rating", color="green");
mp.ylabel("Enrollment", color="green");

# %% [markdown]
# We can see that enrollments are higher when average rating is within the range of 4.2 to 4.7 approximately.

# %% [markdown]
# ## 1.7 Count Plots

# %%
# different course categories
print(df["course_category"].value_counts())
mp.figure(figsize=(9,5))
sb.countplot(data=df, x="course_category")
# Out:
# business_&_education    510
# development             361
# it_software             343
# hobby                   124
# design                  117
# Name: course_category, dtype: int64
# <AxesSubplot:xlabel='course_category', ylabel='count'>

# %% [markdown]
# We can see that we have higher number of counts for business and education followed by development and then IT Software.

# %%
df.describe()
# Out:
#         avg_rating  number_ratings    enrollment  last_updated     lectures  \
# count  1455.000000     1455.000000   1455.000000   1455.000000  1455.000000
# mean      4.419038     1767.973883  10289.908591     19.838811   101.873540
# std       0.211047     1775.029145   9670.746992      1.357742    93.447558
# min       3.800000       17.000000     36.000000     11.670000     5.000000
# 25%       4.300000      540.000000   3266.000000     19.420000    43.500000
# 50%       4.400000     1100.000000   6852.000000     20.420000    72.000000
# 75%       4.600000     2380.000000  14423.000000     20.750000   124.000000
# max       4.900000     9748.000000  49052.000000     20.830000   696.000000
#
#           duration       price2     discount  inst_rating    inst_review  \
# count  1455.000000  1455.000000  1455.000000  1455.000000    1455.000000
# mean     11.420859    23.906838    78.516838     4.413471   14460.281100
# ...

# %% [markdown]
# ### 1.7.2 The different categories of courses whose enrollment is higher than 75% percentile of its value

# %%
# find out the indexes of the data with enrollment is higher than 75% percentile 
df.enrollment> 14423.000000
# to find the index
ind2 = df.loc[df.enrollment> 14423.000000].index
print(ind2)

# display the data
enrollment_Count = df.iloc[ind2]
enrollment_Count[['course_category','enrollment']]


print(enrollment_Count["course_category"].value_counts())
mp.figure(figsize=(9,5))
sb.countplot(data=df, x="course_category")
# Out:
# Int64Index([   0,   10,   12,   26,   35,   40,   41,   44,   56,   58,
#             ...
#             1431, 1434, 1436, 1437, 1438, 1442, 1443, 1445, 1446, 1454],
#            dtype='int64', length=364)
# business_&_education    147
# development             104
# it_software              57
# design                   32
# hobby                    24
# Name: course_category, dtype: int64
# <AxesSubplot:xlabel='course_category', ylabel='count'>

# %% [markdown]
# We can see that we have higher number of enrollments for business and education followed by development and then It Software than 75% percentile of its value.

# %% [markdown]
# ### 1.7.3 The different categories of courses whose average ratings is lower than 25% percentile of its value

# %%
# find out the indexes of the data with average ratings is lower than 25% percentile
df.avg_rating< 4.300000
# to find the index
ind2 = df.loc[df.avg_rating< 4.300000].index
print(ind2)

# display the data
avg_rating_Count = df.iloc[ind2]
avg_rating_Count[['course_category','avg_rating']]


print(avg_rating_Count["course_category"].value_counts())
mp.figure(figsize=(9,5))
sb.countplot(data=df, x="course_category")
# Out:
# Int64Index([   3,   13,   18,   22,   23,   30,   32,   43,   47,   50,
#             ...
#             1410, 1423, 1424, 1426, 1432, 1433, 1444, 1447, 1452, 1453],
#            dtype='int64', length=282)
# it_software             95
# business_&_education    92
# development             69
# design                  19
# hobby                    7
# Name: course_category, dtype: int64
# <AxesSubplot:xlabel='course_category', ylabel='count'>

# %% [markdown]
# We can see that we have lower number of average of ratings for business and education followed by development and then It Software than 25% percentile of its value.

# %% [markdown]
# ## 1.8 Displaying correlation and the summary statistics

# %%
# correlation
df.corr()

# plotting correlation heatmap
dataplot=sb.heatmap(df.corr())

# displaying heatmap
mp.show()

# %%
df.describe()
df.corr()
# Out:
#                 avg_rating  number_ratings  enrollment  last_updated  \
# avg_rating        1.000000        0.200454    0.207510     -0.013175
# number_ratings    0.200454        1.000000    0.853691     -0.011226
# enrollment        0.207510        0.853691    1.000000     -0.039707
# last_updated     -0.013175       -0.011226   -0.039707      1.000000
# lectures          0.019096        0.010322    0.007326      0.077893
# duration         -0.017504        0.026363    0.019542      0.085966
# price2           -0.082052       -0.035223   -0.049769     -0.010121
# discount         -0.001695       -0.011101    0.003227      0.068650
# inst_rating       0.736497        0.242893    0.237112      0.030413
# inst_review       0.188549        0.346876    0.380016      0.065714
# inst_student      0.127469        0.308930    0.421044      0.042089
# inst_course      -0.062877       -0.036057   -0.024146     -0.035199
#
# ...

# %% [markdown]
# ## 1.9 Feature Engineering

# %%
# transforming course category into dummy values
dummy_features = pd.get_dummies(df.course_category, drop_first = True, prefix = 'cat')
dummy_features

# dropping the unwanted column
df.drop(['course_category'], axis=1, inplace = True)
# reseting the index
df.reset_index(inplace=True, drop=True)
df

df = pd.concat([df,dummy_features], axis = 1)
df
# Out:
#       avg_rating  number_ratings  enrollment  last_updated  lectures  \
# 0            4.6          6833.0     21218.0         20.83      53.0
# 1            4.5          2826.0     14269.0         20.83      41.0
# 2            4.4           991.0      3563.0         20.67      91.0
# 3            4.2           681.0      1932.0         20.83      57.0
# 4            4.3          1939.0     14048.0         13.33     142.0
# ...          ...             ...         ...           ...       ...
# 1450         4.4           906.0      5293.0         20.83      43.0
# 1451         4.4           345.0      6212.0         20.83      10.0
# 1452         3.8           693.0      3254.0         20.75      20.0
# 1453         4.2          3459.0     13987.0         15.50      30.0
# 1454         4.5          4546.0     15793.0         20.50     267.0
#
#       duration  price2  discount  inst_rating  inst_review  inst_student  \
# ...

# %% [markdown]
# ## 1.10 Saving Prepared dataset

# %%
# prepared dataset is saved in csv file
df.to_csv("Lab02_GSh43374_prepared.csv",index = False)
